# %%
##  "attacks" thư mục (với các tệp csv tấn công) là cần thiết cho hoạt động của chương trình.
##  "attacks" thư mục phải được đặt trong cùng thư mục với chương trình.


##  Mục đích của mã này là xác định các tính năng sẽ sử dụng trong giai đoạn học máy.
##  cho mục đích này, trọng số của các cuộc tấn công được tính toán.
##  tính toán này được thực hiện bằng cách sử dụng sklearn-RandomForestRegressor.

##  một số phần mã được sử dụng để tính toán và vẽ đồ thị được lấy từ trang web sau.
##  http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html

import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time
seconds = time.time()

def folder(f_name): #hàm này tạo một thư mục có tên "feaure_pics" trong thư mục chương trình.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")
        

# CSV files names:
csv_files=os.listdir("attacks")# It creates a list of file names in the "attacks" folder.

# Headers of column
main_labels=["Flow Duration","Total Fwd Packets",   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
   "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
   "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
   "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
   "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
   "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
   "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
   "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
   "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
   "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min",
    "Idle Mean","Idle Std","Idle Max", "Idle Min","Label"]

ths = open("importance_list_for_attack_files.csv", "w")
folder("./feaure_pics/")
for j in csv_files:
    df=pd.read_csv(".\\attacks\\"+j,usecols=main_labels)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)           
    df["Label"]=attack_or_not

    y = df["Label"].values
    del df["Label"]
    X = df.values
   

    #computing the feature importances
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances  
    count=0
    fea_ture=j[0:-4]+"=["
    for i in impor_bars.index:
        fea_ture=fea_ture+"\""+str(i)+"\","
        count+=1
        if count==5:
            fea_ture=fea_ture[0:-1]+"]"
            break     
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("./feaure_pics/"+j[0:-4]+".pdf",bbox_inches='tight', papertype = 'a4', orientation = 'portrait', format = 'pdf')
    ths.write((  fea_ture ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

    
print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# Bot importance list:
# Bot
#                               importance
# Features
# Bwd Packet Length Mean         0.304463
# Bwd Packet Length Max          0.063685
# Flow IAT Min                   0.041148
# Total Length of Bwd Packets    0.034640
# Flow Duration                  0.002625
# Flow IAT Mean                  0.001879
# Flow Packets/s                 0.001352
# Flow Bytes/s                   0.000994
# Fwd Packet Length Max          0.000865
# Fwd Packet Length Mean         0.000769
# Flow IAT Max                   0.000626
# Bwd Packet Length Std          0.000562
# Total Fwd Packets              0.000476
# Fwd Packet Length Std          0.000468
# Fwd IAT Total                  0.000437
# Total Length of Fwd Packets    0.000414
# Flow IAT Std                   0.000390
# Fwd Packet Length Min          0.000369
# Total Backward Packets         0.000272
# Bwd Packet Length Min          0.000038
#
#
#
# Bot=["Bwd Packet Length Mean","Bwd Packet Length Max","Flow IAT Min","Total Length of Bwd Packets","Flow Duration"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS importance list:
# DDoS
#                               importance
# Features
# Fwd Packet Length Max          0.640940
# Total Length of Fwd Packets    0.173277
# Flow IAT Min                   0.003945
# Flow IAT Mean                  0.001999
# Fwd IAT Total                  0.001700
# Flow IAT Max                   0.001489
# Flow IAT Std                   0.001322
# Flow Duration                  0.001274
# Flow Bytes/s                   0.000931
# Bwd Packet Length Mean         0.000485
# Bwd Packet Length Max          0.000427
# Flow Packets/s                 0.000378
# Bwd Packet Length Min          0.000264
# Total Length of Bwd Packets    0.000261
# Fwd Packet Length Std          0.000236
# Bwd Packet Length Std          0.000213
# Total Backward Packets         0.000168
# Total Fwd Packets              0.000090
# Fwd Packet Length Mean         0.000005
# Fwd Packet Length Min          0.000000
#
#
#
# DDoS=["Fwd Packet Length Max","Total Length of Fwd Packets","Flow IAT Min","Flow IAT Mean","Fwd IAT Total"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS GoldenEye importance list:
# DoS GoldenEye
#                               importance
# Features
# Flow IAT Mean                  0.218390
# Flow IAT Max                   0.143975
# Flow Packets/s                 0.121009
# Flow IAT Min                   0.007594
# Bwd Packet Length Min          0.004779
# Total Backward Packets         0.001877
# Flow Duration                  0.001698
# Fwd Packet Length Min          0.001550
# Fwd Packet Length Max          0.000541
# Fwd IAT Total                  0.000455
# Bwd Packet Length Mean         0.000383
# Bwd Packet Length Max          0.000321
# Bwd Packet Length Std          0.000312
# Total Length of Bwd Packets    0.000261
# Flow Bytes/s                   0.000153
# Flow IAT Std                   0.000145
# Total Length of Fwd Packets    0.000108
# Fwd Packet Length Std          0.000101
# Fwd Packet Length Mean         0.000064
# Total Fwd Packets              0.000042
#
#
#
# DoS GoldenEye=["Flow IAT Mean","Flow IAT Max","Flow Packets/s","Flow IAT Min","Bwd Packet Length Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Hulk importance list:
# DoS Hulk
#                               importance
# Features
# Fwd Packet Length Min          0.153511
# Bwd Packet Length Std          0.114233
# Fwd Packet Length Std          0.014032
# Fwd Packet Length Max          0.009075
# Flow Bytes/s                   0.006537
# Flow IAT Min                   0.004714
# Flow Duration                  0.003757
# Total Length of Bwd Packets    0.001476
# Flow IAT Max                   0.001102
# Fwd IAT Total                  0.000777
# Flow IAT Mean                  0.000483
# Flow Packets/s                 0.000310
# Fwd Packet Length Mean         0.000164
# Flow IAT Std                   0.000142
# Bwd Packet Length Mean         0.000095
# Total Fwd Packets              0.000091
# Total Length of Fwd Packets    0.000044
# Bwd Packet Length Min          0.000044
# Total Backward Packets         0.000041
# Bwd Packet Length Max          0.000018
#
#
#
# DoS Hulk=["Fwd Packet Length Min","Bwd Packet Length Std","Fwd Packet Length Std","Fwd Packet Length Max","Flow Bytes/s"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Slowhttptest importance list:
# DoS Slowhttptest
#                               importance
# Features
# Flow IAT Mean                  0.578825
# Fwd Packet Length Std          0.055028
# Bwd Packet Length Mean         0.042519
# Flow IAT Min                   0.009727
# Total Length of Bwd Packets    0.007634
# Fwd Packet Length Min          0.007215
# Bwd Packet Length Max          0.003125
# Fwd Packet Length Mean         0.001151
# Fwd Packet Length Max          0.001139
# Bwd Packet Length Std          0.001099
# Flow Duration                  0.000610
# Flow IAT Max                   0.000461
# Fwd IAT Total                  0.000425
# Bwd Packet Length Min          0.000239
# Flow Bytes/s                   0.000239
# Total Backward Packets         0.000232
# Flow Packets/s                 0.000165
# Total Length of Fwd Packets    0.000097
# Total Fwd Packets              0.000081
# Flow IAT Std                   0.000064
#
#
#
# DoS Slowhttptest=["Flow IAT Mean","Fwd Packet Length Std","Bwd Packet Length Mean","Flow IAT Min","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS slowloris importance list:
# DoS slowloris
#                               importance
# Features
# Bwd Packet Length Mean         0.329956
# Flow IAT Std                   0.050765
# Fwd Packet Length Min          0.039825
# Flow Packets/s                 0.010166
# Flow IAT Mean                  0.008164
# Total Backward Packets         0.002872
# Fwd IAT Total                  0.001144
# Bwd Packet Length Std          0.001072
# Flow Bytes/s                   0.001056
# Fwd Packet Length Max          0.001008
# Fwd Packet Length Mean         0.000938
# Total Fwd Packets              0.000930
# Total Length of Fwd Packets    0.000913
# Flow IAT Max                   0.000818
# Flow Duration                  0.000665
# Flow IAT Min                   0.000577
# Bwd Packet Length Max          0.000481
# Total Length of Bwd Packets    0.000395
# Fwd Packet Length Std          0.000380
# Bwd Packet Length Min          0.000220
#
#
#
# DoS slowloris=["Bwd Packet Length Mean","Flow IAT Std","Fwd Packet Length Min","Flow Packets/s","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# FTP-Patator importance list:
# FTP-Patator
#                               importance
# Features
# Fwd Packet Length Std          0.040030
# Fwd Packet Length Mean         0.031686
# Fwd Packet Length Max          0.025166
# Flow IAT Min                   0.002729
# Bwd Packet Length Min          0.001378
# Flow IAT Mean                  0.000456
# Flow IAT Max                   0.000454
# Flow Packets/s                 0.000423
# Flow Duration                  0.000298
# Fwd IAT Total                  0.000067
# Flow Bytes/s                   0.000050
# Fwd Packet Length Min          0.000036
# Total Fwd Packets              0.000027
# Total Length of Bwd Packets    0.000026
# Bwd Packet Length Mean         0.000026
# Total Length of Fwd Packets    0.000018
# Total Backward Packets         0.000013
# Bwd Packet Length Max          0.000013
# Bwd Packet Length Std          0.000012
# Flow IAT Std                   0.000000
#
#
#
# FTP-Patator=["Fwd Packet Length Std","Fwd Packet Length Mean","Fwd Packet Length Max","Flow IAT Min","Bwd Packet Length Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Heartbleed importance list:
# Heartbleed
#                               importance
# Features
# Flow IAT Max                      0.052
# Flow IAT Std                      0.048
# Flow Duration                     0.036
# Fwd IAT Total                     0.036
# Bwd Packet Length Mean            0.032
# Total Fwd Packets                 0.028
# Total Length of Fwd Packets       0.028
# Total Backward Packets            0.028
# Total Length of Bwd Packets       0.024
# Bwd Packet Length Max             0.024
# Bwd Packet Length Std             0.020
# Flow IAT Min                      0.020
# Fwd Packet Length Max             0.012
# Flow Bytes/s                      0.008
# Flow Packets/s                    0.004
# Fwd Packet Length Min             0.000
# Fwd Packet Length Mean            0.000
# Fwd Packet Length Std             0.000
# Flow IAT Mean                     0.000
# Bwd Packet Length Min             0.000
#
#
#
# Heartbleed=["Flow IAT Max","Flow IAT Std","Flow Duration","Fwd IAT Total","Bwd Packet Length Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Flow Duration                       0.0
# Total Fwd Packets                   0.0
# Flow IAT Min                        0.0
# Flow IAT Max                        0.0
# Flow IAT Std                        0.0
# Flow IAT Mean                       0.0
# Flow Packets/s                      0.0
# Flow Bytes/s                        0.0
# Bwd Packet Length Std               0.0
# Bwd Packet Length Mean              0.0
# Bwd Packet Length Min               0.0
# Bwd Packet Length Max               0.0
# Fwd Packet Length Std               0.0
# Fwd Packet Length Mean              0.0
# Fwd Packet Length Min               0.0
# Fwd Packet Length Max               0.0
# Total Length of Bwd Packets         0.0
# Total Length of Fwd Packets         0.0
# Total Backward Packets              0.0
# Fwd IAT Total                       0.0
#
#
#
# Infiltration=["Flow Duration","Total Fwd Packets","Flow IAT Min","Flow IAT Max","Flow IAT Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# PortScan importance list:
# PortScan
#                               importance
# Features
# Total Length of Fwd Packets    0.397214
# Bwd Packet Length Min          0.027119
# Flow Bytes/s                   0.013471
# Flow IAT Mean                  0.001185
# Flow IAT Min                   0.000749
# Flow Duration                  0.000670
# Flow Packets/s                 0.000654
# Bwd Packet Length Mean         0.000603
# Flow IAT Max                   0.000555
# Flow IAT Std                   0.000527
# Fwd IAT Total                  0.000401
# Total Length of Bwd Packets    0.000237
# Total Backward Packets         0.000138
# Bwd Packet Length Std          0.000104
# Fwd Packet Length Mean         0.000060
# Fwd Packet Length Max          0.000038
# Total Fwd Packets              0.000020
# Fwd Packet Length Std          0.000020
# Fwd Packet Length Min          0.000002
# Bwd Packet Length Max          0.000002
#
#
#
# PortScan=["Total Length of Fwd Packets","Bwd Packet Length Min","Flow Bytes/s","Flow IAT Mean","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Flow Bytes/s                   0.030528
# Flow IAT Mean                  0.001178
# Flow IAT Max                   0.000919
# Flow Packets/s                 0.000864
# Flow Duration                  0.000862
# Fwd IAT Total                  0.000848
# Bwd Packet Length Min          0.000650
# Flow IAT Min                   0.000624
# Bwd Packet Length Max          0.000465
# Fwd Packet Length Min          0.000336
# Flow IAT Std                   0.000322
# Total Length of Bwd Packets    0.000313
# Bwd Packet Length Mean         0.000272
# Total Backward Packets         0.000192
# Fwd Packet Length Max          0.000095
# Fwd Packet Length Mean         0.000093
# Total Fwd Packets              0.000083
# Bwd Packet Length Std          0.000034
# Total Length of Fwd Packets    0.000033
# Fwd Packet Length Std          0.000018
#
#
#
# SSH-Patator=["Flow Bytes/s","Flow IAT Mean","Flow IAT Max","Flow Packets/s","Flow Duration"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Flow Duration                       0.0
# Total Fwd Packets                   0.0
# Flow IAT Min                        0.0
# Flow IAT Max                        0.0
# Flow IAT Std                        0.0
# Flow IAT Mean                       0.0
# Flow Packets/s                      0.0
# Flow Bytes/s                        0.0
# Bwd Packet Length Std               0.0
# Bwd Packet Length Mean              0.0
# Bwd Packet Length Min               0.0
# Bwd Packet Length Max               0.0
# Fwd Packet Length Std               0.0
# Fwd Packet Length Mean              0.0
# Fwd Packet Length Min               0.0
# Fwd Packet Length Max               0.0
# Total Length of Bwd Packets         0.0
# Total Length of Fwd Packets         0.0
# Total Backward Packets              0.0
# Fwd IAT Total                       0.0
#
#
#
# Web Attack=["Flow Duration","Total Fwd Packets","Flow IAT Min","Flow IAT Max","Flow IAT Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  2078.0644187927246 seconds
